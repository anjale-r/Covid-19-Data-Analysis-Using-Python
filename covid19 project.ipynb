# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("D:/New folder/Python/Coursera/covid/covid19_Confirmed_dataset.csv")
data
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN         Western Sahara  24.215500 -12.885800        0
# 262            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 263            NaN                  Yemen  15.552727  48.516388        0
# 264            NaN                Comoros -11.645500  43.333300        0
# 265            NaN             Tajikistan  38.861034  71.276093        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  \
# ...

# %%
data.shape
# Out:
# (266, 104)

# %% [markdown]
# Deleting useless columns

# %%
data.drop(['Lat','Long'],axis=1,inplace=True)

# %%
data.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
# Aggregating the rows by the country

# %%
data_aggregated = data.groupby("Country/Region").sum()
# Out:
# C:\Users\ajayd\AppData\Local\Temp\ipykernel_26048\1842523634.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_aggregated = data.groupby("Country/Region").sum()

# %%
data_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
data_aggregated.shape
# Out:
# (187, 100)

# %% [markdown]
# Visualizing data related to a country for example China

# %%
data_aggregated.loc['China'].plot()
data_aggregated.loc['Italy'].plot()
data_aggregated.loc['Spain'].plot()
plt.legend()

# %% [markdown]
# Calculating a good measure
#
#
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
data_aggregated.loc['China'].plot()
# Out:
# <Axes: >

# %% [markdown]
# ploting first derivative of the curve

# %%
data_aggregated.loc['China'].diff().plot()
# Out:
# <Axes: >

# %% [markdown]
# find maximum infection rate

# %%
data_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %%
data_aggregated.loc['Italy'].diff().max()
# Out:
# 6557.0

# %%
data_aggregated.loc['Spain'].diff().max()
# Out:
# 9630.0

# %% [markdown]
# max infection rate for all countries

# %%
countries = list(data_aggregated.index)
max_infection_rates = []
for country in countries :
    max_infection_rates.append(data_aggregated.loc[country].diff().max())
data_aggregated['max infection rate'] = max_infection_rates

# %%
data_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %%
covid_data_new = pd.DataFrame(data_aggregated['max infection rate'])

# %%
covid_data_new
# Out:
#                     max infection rate
# Country/Region
# Afghanistan                      232.0
# Albania                           34.0
# Algeria                          199.0
# Andorra                           43.0
# Angola                             5.0
# ...                                ...
# West Bank and Gaza                66.0
# Western Sahara                     4.0
# Yemen                              5.0
# Zambia                             9.0
# Zimbabwe                           8.0
#
# [187 rows x 1 columns]

# %% [markdown]
# Importing world happiness report

# %%
world_happiness_data=pd.read_csv("D:/New folder/Python/Coursera/covid/worldwide_happiness_report.csv")

# %%
world_happiness_data
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
world_happiness_data.shape
# Out:
# (156, 9)

# %%
columns_to_dropped = ['Overall rank','Score','Generosity','Perceptions of corruption']
world_happiness_data.drop(columns_to_dropped,axis=1 , inplace=True)

# %%
world_happiness_data
# Out:
#             Country or region  GDP per capita  Social support  \
# 0                     Finland           1.340           1.587
# 1                     Denmark           1.383           1.573
# 2                      Norway           1.488           1.582
# 3                     Iceland           1.380           1.624
# 4                 Netherlands           1.396           1.522
# ..                        ...             ...             ...
# 151                    Rwanda           0.359           0.711
# 152                  Tanzania           0.476           0.885
# 153               Afghanistan           0.350           0.517
# 154  Central African Republic           0.026           0.000
# 155               South Sudan           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices
# 0                      0.986                         0.596
# 1                      0.996                         0.592
# ...

# %% [markdown]
# changing the indices of the dataframe

# %%
world_happiness_data.set_index(['Country or region'],inplace=True)
world_happiness_data.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# ### join two datasets we have prepared

# %%
data_new=world_happiness_data.join(covid_data_new).copy()

# %%
data_new
# Out:
#                           GDP per capita  Social support  \
# Country or region
# Finland                            1.340           1.587
# Denmark                            1.383           1.573
# Norway                             1.488           1.582
# Iceland                            1.380           1.624
# Netherlands                        1.396           1.522
# ...                                  ...             ...
# Rwanda                             0.359           0.711
# Tanzania                           0.476           0.885
# Afghanistan                        0.350           0.517
# Central African Republic           0.026           0.000
# South Sudan                        0.306           0.575
#
#                           Healthy life expectancy  \
# Country or region
# Finland                                     0.986
# Denmark                                     0.996
# Norway                                      1.028
# ...

# %% [markdown]
# Correlation matrix

# %%
data_new.corr()
# Out:
#                               GDP per capita  Social support  \
# GDP per capita                      1.000000        0.754906
# Social support                      0.754906        1.000000
# Healthy life expectancy             0.835462        0.719009
# Freedom to make life choices        0.379079        0.447333
# max infection rate                  0.250118        0.191958
#
#                               Healthy life expectancy  \
# GDP per capita                               0.835462
# Social support                               0.719009
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.390395
# max infection rate                           0.289263
#
#                               Freedom to make life choices  max infection rate
# GDP per capita                                    0.379079            0.250118
# Social support                                    0.447333            0.191958
# ...

# %% [markdown]
# ### Data Visualisation

# %% [markdown]
# Plotting GDP vs maximum Infection rate

# %%
x = data_new['GDP per capita']
y = data_new['max infection rate']
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max infection rate'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max infection rate'>

# %% [markdown]
#  Plotting Social support vs maximum Infection rate

# %%
x = data_new['Social support']
y = data_new['max infection rate']
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='max infection rate'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='max infection rate'>

# %% [markdown]
# Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data_new['Healthy life expectancy']
y = data_new['max infection rate']
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='max infection rate'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='max infection rate'>

# %% [markdown]
# Plotting Freedom to make life choices vs maximum Infection rate

# %%
x = data_new['Freedom to make life choices']
y = data_new['max infection rate']
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='max infection rate'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='max infection rate'>
